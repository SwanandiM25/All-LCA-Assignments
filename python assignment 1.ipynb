# %%
#ASSIGNMENT 1- python program to create and store student information using dictionary
my_dict = {"Name":"Shradha Patil", "Roll number":35, "Branch":"WPU kothrud","Marks":{"Maths":92,"physics":90,"chemistry":88}}

my_dict["Age"] = 19
my_dict.pop("Roll number")
my_dict["Marks"].update({"Maths":80}) 

print(my_dict)
# Out:
# {'Name': 'Shradha Patil', 'Branch': 'WPU kothrud', 'Marks': {'Maths': 80, 'physics': 90, 'chemistry': 88}, 'Age': 19}

# %%
#ASSIGNMENT 2 - program to find largest of 3 numbers
a = int(input("Enter a = "))
b = int(input("Enter b = "))
c = int(input("Enter c = "))

print("Largest number among a,b and c is = ",max(a,b,c))
# Out:
# Enter a =  2
# Enter b =  3
# Enter c =  4
# Largest number among a,b and c is =  4

# %%
#ASSIGNMENT 3 - program to find whether the triangle is right angled or not
def right_triangle(a, b, c):
    sides = [a, b, c]
    sides.sort()   

    if sides[0]**2 + sides[1]**2 == sides[2]**2:
        return True
    else:
        return False

a = float(input("Enter first side: "))
b = float(input("Enter second side: "))
c = float(input("Enter third side: "))

if right_triangle(a, b, c):
    print("The triangle is a right-angled triangle.")
else:
    print("The triangle is not a right-angled triangle.")
# Out:
# Enter first side:  3
# Enter second side:  4
# Enter third side:  5
# The triangle is a right-angled triangle.
