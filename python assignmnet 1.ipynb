# %%
#1st q- assign 5 elements in dictionary and Add and delete student
my_dict={
    "Full Name":"Shradha Patil",
    "Age":19,
    "DOB":"2/8/2007",
    "Contact number":"xxxxxxxxx",
    "Address" : "A5 grand , sinhagad road pune"
 
}
my_dict["Student Email-id"]="shradha.patil@gmail.com"

my_dict.pop("Address")

print(my_dict)
# Out:
# {'Full Name': 'Shradha Patil', 'Age': 19, 'DOB': '2/8/2007', 'Contact number': 'xxxxxxxxx', 'Student Email-id': 'shradha.patil@gmail.com'}

# %%
#2nd q - convert list to dict
key=["Full Name","Age","DOB","Contact number","Address" ]
values=["Shradha Patil",19,"02/08/2007","123456789","A5 grand , sinhagad road pune"]

result=dict(zip(key,values))

print("my dict=",result)
# Out:
# my dict= {'Full Name': 'Shradha Patil', 'Age': 19, 'DOB': '02/08/2007', 'Contact number': '123456789', 'Address': 'A5 grand , sinhagad road pune'}

# %%
#3rd question - Sorting elements
my_dict={"name":"shradha","panel":"B","roll no":34,"marks":[65,87,67,94]}
print(sorted(my_dict))
# Out:
# ['marks', 'name', 'panel', 'roll no']

# %%
#4th q - convert dict to list
my_dict={"Full Name":"Shradha Patil",
    "Age":19,
    "DOB":"02/08/2007",
    "Contact number":"123456789",
    "Address" : "A5 grand , sinhagad road pune"}

print(list(my_dict.keys()))
print(list(my_dict.values()))
# Out:
# ['Full Name', 'Age', 'DOB', 'Contact number', 'Address']
# ['Shradha Patil', 19, '02/08/2007', '123456789', 'A5 grand , sinhagad road pune']

# %%
#5thq - find mean of values in dict
my_dict={"marks1":39,"marks2":45,"marks3":89,"marks4":67,"marks5":77}
print(my_dict.values())

mean=(sum(my_dict.values()))/len(my_dict)

print(mean)
# Out:
# dict_values([39, 45, 89, 67, 77])
# 63.4

# %%
#6th q - display 1)Dev 2)12 roll no 3) greatest marks
my_dict={'name':['Yash','Neel','Dev'],'roll no':[11,12,13],'marks':[78,56,98]}
print("name = ",my_dict['name'][2])
print("roll no =",my_dict['roll no'][1])
print("greatest marks = ",max(my_dict['marks']))
# Out:
# name =  Dev
# roll no = 12
# greatest marks =  98

# %%
#7th q - calculate frequency of letters in a string
s = input("Enter a string: ")
freq = {}
for ch in s:
    if ch in freq:
        freq[ch] = freq[ch] + 1
    else:
        freq[ch] = 1
print(freq)
# Out:
# Enter a string:  name
# {'n': 1, 'a': 1, 'm': 1, 'e': 1}

# %%
#8th q - write program to input num and denom and gives output as quotient and remainder 
numerator=int(input("Enter numerator = "))
denominator=int(input("Enter denominator = "))

Remainder=numerator%denominator

Quotient=numerator/denominator

print(tuple((Remainder,Quotient)))
# Out:
# Enter numerator =  23
# Enter denominator =  45
# (23, 0.5111111111111111)

# %%
#9th q - program to create 2 date tuples and finding number of days between the dates
d1=int(input("Enter day of first date: "))
m1=int(input("Enter month of first date: "))
y1=int(input("Enter year of first date: "))
date1=(d1, m1, y1)

d2=int(input("Enter day of second date: "))
m2=int(input("Enter month of second date: "))
y2=int(input("Enter year of second date: "))
date2=(d2, m2, y2)

days=[31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31]

#Converting first date into number of days
total1= y1 * 365
for i in range(m1 - 1):
    total1 = total1 + days[i]

total1=total1 + d1

#Converting second date into number of days
total2= y2 * 365
for i in range(m2 - 1):
    total2 = total2 + days[i]

total2=total2 + d2

difference = total2 - total1

if difference < 0:
    difference=-difference

print("Number of days between the dates =", difference)
# Out:
# Enter day of first date:  34
# Enter month of first date:  5
# Enter year of first date:  2008
# Enter day of second date:  3
# Enter month of second date:  5
# Enter year of second date:  2009
# Number of days between the dates = 334
