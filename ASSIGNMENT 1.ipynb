# %%
#ASSIGNMENT 1- python program to create and store student information using dictionary
my_dict = {
    35: ("Shradha Patil", "WPU Kothrud", [92, 90, 88])
}

my_dict[36] = ("Rahul Sharma", "WPU Kothrud", [85, 88, 90])
my_dict.pop(36)
my_dict[35] = ("Shradha Patil", "WPU Kothrud", [80, 90, 88])
print(my_dict)
