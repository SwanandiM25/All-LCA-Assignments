# %%
#ASSIGNMENT 4 - performing matrix addition
import numpy as np
a=[[1,2,3],
   [4,5,6],
   [7,8,9]]
b=[[1,2,3],
   [4,5,6],
   [7,8,9]]

a=np.array(a)
b=np.array(b)

result=np.add(a,b)
print(result)
